# %% [markdown]
# # FIFA World Cup 2022 Simulation

# %% [markdown]
# Import libraries

# %%
from datetime import datetime

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import plotly.express as px
import plotly.offline as py

from sklearn.model_selection import train_test_split

# %% [markdown]
# Common data

# %%
groups = pd.DataFrame.from_dict({
    'A': ['Qatar', 'Ecuador', 'Senegal', 'Netherlands'],
    'B': ['England', 'Iran', 'United States', 'Wales'],
    'C': ['Argentina', 'Saudi Arabia', 'Mexico', 'Poland'],
    'D': ['France', 'Australia', 'Denmark', 'Tunisia'],
    'E': ['Spain', 'Costa Rica', 'Germany', 'Japan'],
    'F': ['Belgium', 'Canada', 'Morocco', 'Croatia'],
    'G': ['Brazil', 'Serbia', 'Switzerland', 'Cameroon'],
    'H': ['Portugal', 'Ghana', 'Uruguay', 'South Korea'],
})
groups
# Out:
#              A              B             C          D           E        F  \
# 0        Qatar        England     Argentina     France       Spain  Belgium
# 1      Ecuador           Iran  Saudi Arabia  Australia  Costa Rica   Canada
# 2      Senegal  United States        Mexico    Denmark     Germany  Morocco
# 3  Netherlands          Wales        Poland    Tunisia       Japan  Croatia
#
#              G            H
# 0       Brazil     Portugal
# 1       Serbia        Ghana
# 2  Switzerland      Uruguay
# 3     Cameroon  South Korea

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Results dataset

# %% [markdown]
# Read dataset

# %%
results = pd.read_csv('results.csv')

# %%
results.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England         0.0         0.0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland         4.0         2.0   Friendly   London
# 2  1874-03-07  Scotland   England         2.0         1.0   Friendly  Glasgow
# 3  1875-03-06   England  Scotland         2.0         2.0   Friendly   London
# 4  1876-03-04  Scotland   England         3.0         0.0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
results.describe()
# Out:
#          home_score    away_score
# count  44059.000000  44059.000000
# mean       1.740507      1.178306
# std        1.747525      1.394815
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       31.000000     21.000000

# %%
results.dtypes
# Out:
# date           object
# home_team      object
# away_team      object
# home_score    float64
# away_score    float64
# tournament     object
# city           object
# country        object
# neutral          bool
# dtype: object

# %% [markdown]
# Convert date to datime

# %%
results['date'] = pd.to_datetime(results['date'])
# Out:
# date          datetime64[ns]
# home_team             object
# away_team             object
# home_score           float64
# away_score           float64
# tournament            object
# city                  object
# country               object
# neutral                 bool
# dtype: object

# %% [markdown]
# #### Teams

# %%
px.histogram(results.sort_values('home_team'), x="home_team")
# Out:
# <div>                            <div id="a75f7230-8b28-432c-afaa-6527d35de2e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a75f7230-8b28-432c-afaa-6527d35de2e9")) {                    Plotly.newPlot(                        "a75f7230-8b28-432c-afaa-6527d35de2e9",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"home_team=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Abkhazia","Abkhazia","Abkhazia","Abkhazia","Abkhazia","Abkhazia","Abkhazia","Abkhazia","Abkhazia","Abkhazia","Abkhazia","Abkhazia","Abkhazia","Abkhazia","Abkhazia","Abkhazia","Abkhazia","Abkhazia","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Alderney","Alderney","Alderney","Alderney","Alderney","Alderney","Alderney","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Alger ...

# %% [markdown]
# Keep only classified countries

# %%
results = results[
    results['home_team'].isin(groups.values.reshape(-1,).tolist())
    & results['away_team'].isin(groups.values.reshape(-1,).tolist())
]
results
# Out:
#             date     home_team      away_team  home_score  away_score  \
# 10    1879-01-18       England          Wales         2.0         1.0
# 14    1880-03-15         Wales        England         2.0         3.0
# 16    1881-02-26       England          Wales         0.0         1.0
# 22    1882-03-13         Wales        England         5.0         3.0
# 24    1883-02-03       England          Wales         5.0         0.0
# ...          ...           ...            ...         ...         ...
# 44028 2022-09-27       Ecuador          Japan         0.0         0.0
# 44034 2022-09-27          Iran        Senegal         1.0         1.0
# 44036 2022-09-27   South Korea       Cameroon         1.0         0.0
# 44046 2022-09-27  Saudi Arabia  United States         0.0         0.0
# 44050 2022-09-27      Portugal          Spain         0.0         1.0
#
#                 tournament              city      country  neutral
# 10                Friendly            London      England    False
# 14                Friendly           Wrexham        Wales    False
# 16                Friendly         Blackburn      England    False
# 22                Friendly           Wrexham        Wales    False
# 24                Friendly            London      England    False
# ...                    ...               ...          ...      ...
# 44028  Kirin Challenge Cup        Düsseldorf      Germany     True
# 44034             Friendly  Maria Enzersdorf      Austria     True
# 44036             Friendly             Seoul  South Korea    False
# 44046             Friendly            Murcia        Spain     True
# 44050  UEFA Nations League             Braga     Portugal    False
#
# [4220 rows x 9 columns]

# %% [markdown]
# #### Dates

# %%
px.histogram(results.sort_values('date'), x="date")
# Out:
# <div>                            <div id="7698434b-8d49-42c3-8ce6-3aaf199765b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7698434b-8d49-42c3-8ce6-3aaf199765b7")) {                    Plotly.newPlot(                        "7698434b-8d49-42c3-8ce6-3aaf199765b7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"date=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["1879-01-18T00:00:00","1880-03-15T00:00:00","1881-02-26T00:00:00","1882-03-13T00:00:00","1883-02-03T00:00:00","1884-03-17T00:00:00","1885-03-14T00:00:00","1885-11-28T00:00:00","1886-03-29T00:00:00","1886-11-25T00:00:00","1887-02-26T00:00:00","1888-02-04T00:00:00","1889-02-23T00:00:00","1890-03-15T00:00:00","1891-03-07T00:00:00","1892-03-05T00:00:00","1893-03-13T00:00:00","1894-03-12T00:00:00","1895-03-18T00:00:00","1896-03-16T00:00:00","1897-03-29T00:00:00","1898-03-28T00:00:00","1899-03-20T00:00:00","1900-03-26T00:00:00","1901-03-18T00:00:00","1902-03-03T00:00:00","1902-07-20T00:00:00","1903-03-02T00:00:00","1903-09-13T00:00:00","1904-02-29T00:00:00","1904-05-01T00:00:00","1905-02-12T00:00:00","1905-03-27T00:00:00","1905-04-30T00:00:00","1905-05-07T00:00:00","1905-05-14T00:00:00","1905-08-15T00:00:00","1906-03-19T00:00:00","1906-04-22T00:00:00","1906-04-29T00:00:00","1906-05-13T00:00:00","1906-08-15T00:00:00","1906-10-21T00:00:00","1907-03-18T00:00:00","1907-04-14T00:00:00","1907-04-21T00:00:00","1907-05-09T00:00:00","1908-03-08T00:00:00","1908-03-16T00:00:00","1908-03-29T00:00:00","1908-04-05T00:00:00","1908-04-12T00:00:00","1908-04-26T00:00:00","1908-05-10T00:00:00","1908-08-15T00:00:00","1908-09-13T00:00:00","1908-10-04T00:00:00","1909-03-15T00:00:00","1909-03-21T00:00:00","1909-04-04T00:00:00","1909-04-25T00:00:00","1909-05-09T00:00:00","1909-08-15T00:00:00","1909-09-19T00:00:00","1909-10-10T00:00:00","1910-03-13T00:00:00","1910-03-14T00:00:00","1910-04-03T00:00:00","1910-04-03T00:00:00","1910-04-10T00:00:00","1910-04-24T00:00:00","1910-05-16T00:00:00","1910-06-12T00:00:00","1910-08-15T00:00:00","1910-10-16T00:00:00","1910-11-13T00:00:00","1910-11-27T00:00:00","1911-03-13T00:00:00","1911-03-19T00:00:00","1911-03-26T00:00:00","1911-04-02T00:00:00","1911-04-23T00:00:00","1911-04-23T00:00:00","1911-04-30T00:00:00","1911-08-15T00:00:00","1911-09-17T00:00:00","1911-10-08T00:00:00","1911-10-22T00:00:00","1911-10-29T00:00:00","1912-01-28T00:00:00","1912-02-18T00:00:00","1912-02-20T00:00:00","1912-03-10T00:00:00","1912-03-11T00:00:00","1912-03-24T00:00:00","1912-04-28T00:00:00","1912-05-05T00:00:00","1912-08-15T00:00:00","1912-08-25T00:00:00","1912-09-22T00:00:00","1912-10-06T00:00:00","1912-10-06T00:00:00","1912-11-17T00:00:00","1912-12-01T00:00:00","1913-02-16T00:00:00","1913-03-09T00:00:00","1913-03-09T00:00:00","1913-03-17T00:00:00","1913-04-20T00:00:00","1913-05-04T00:00:00","1913-05-18T00:00:00","1913-06-15T00:00:00","1913-07-09T00:00:00","1913-08-15T00:00:00","1913-08-31T00:00:00","1913-10-05T00:00:00","1913-10-26T00:00:00","1913-10-26T00:00:00","1913-11-02T00:00:00","1913-11-23T00:00:00","1914-01-25T00:00:00","1914-03-08T00:00:00","1914-03-15T00:00:00","1914-03-16T00:00:00","1914-04-05T00:00:00","1914-04-26T00:00:00","1914-05-17T00:00:00","1914-08-30T00:00:00","1914-09-13T00:00:00","1914-09-20T00:00:00","1914-09-27T00:00:00","1915-07-18T00:00:00","1915-08-15T00:00:00","1915-09-12T00:00:00","1916-07-10T00:00:00","1916-07-12T00:00:00","1916-07-17T00:00:00","1916-07-18T00:00:00","1916-08-15T00:00:00","1916-08-15T00:00:00","1916-10-01T00:00:00","1916-10-01T00:00:00","1916-10-29T00:00:00","1917-07-18T00:00:00","1917-08-15T00:00:00","1917-09-02T00:00:00","1917-10-03T00:00:00", ...

# %%
results = results[results['date'] > datetime(2009, 1, 1)]
results
# Out:
#             date     home_team      away_team  home_score  away_score  \
# 31297 2009-01-05  Saudi Arabia          Qatar         0.0         0.0
# 31391 2009-02-11        France      Argentina         0.0         2.0
# 31394 2009-02-11          Iran    South Korea         1.0         1.0
# 31397 2009-02-11         Japan      Australia         0.0         0.0
# 31414 2009-02-11         Spain        England         2.0         0.0
# ...          ...           ...            ...         ...         ...
# 44028 2022-09-27       Ecuador          Japan         0.0         0.0
# 44034 2022-09-27          Iran        Senegal         1.0         1.0
# 44036 2022-09-27   South Korea       Cameroon         1.0         0.0
# 44046 2022-09-27  Saudi Arabia  United States         0.0         0.0
# 44050 2022-09-27      Portugal          Spain         0.0         1.0
#
#                          tournament              city      country  neutral
# 31297                      Gulf Cup            Muscat         Oman     True
# 31391                      Friendly         Marseille       France    False
# 31394  FIFA World Cup qualification            Tehran         Iran    False
# 31397  FIFA World Cup qualification          Yokohama        Japan    False
# 31414                      Friendly           Seville        Spain    False
# ...                             ...               ...          ...      ...
# 44028           Kirin Challenge Cup        Düsseldorf      Germany     True
# 44034                      Friendly  Maria Enzersdorf      Austria     True
# 44036                      Friendly             Seoul  South Korea    False
# 44046                      Friendly            Murcia        Spain     True
# 44050           UEFA Nations League             Braga     Portugal    False
#
# [924 rows x 9 columns]

# %% [markdown]
# #### Drop unnnecesary columns

# %%
results = results[['date', 'home_team', 'away_team', 'home_score', 'away_score']]
results
# Out:
#             date     home_team      away_team  home_score  away_score
# 31297 2009-01-05  Saudi Arabia          Qatar         0.0         0.0
# 31391 2009-02-11        France      Argentina         0.0         2.0
# 31394 2009-02-11          Iran    South Korea         1.0         1.0
# 31397 2009-02-11         Japan      Australia         0.0         0.0
# 31414 2009-02-11         Spain        England         2.0         0.0
# ...          ...           ...            ...         ...         ...
# 44028 2022-09-27       Ecuador          Japan         0.0         0.0
# 44034 2022-09-27          Iran        Senegal         1.0         1.0
# 44036 2022-09-27   South Korea       Cameroon         1.0         0.0
# 44046 2022-09-27  Saudi Arabia  United States         0.0         0.0
# 44050 2022-09-27      Portugal          Spain         0.0         1.0
#
# [924 rows x 5 columns]

# %% [markdown]
# Create output column

# %%
df = pd.DataFrame()

df['date'], df['home_team'], df['away_team'], df['home_score'], df['away_score'] = np.where(
    results.home_team > results.away_team,
    [results.date, results.away_team, results.home_team, results.away_score, results.home_score],
    [results.date, results.home_team, results.away_team, results.home_score, results.away_score]
)
df
# Out:
#                     date     home_team      away_team home_score away_score
# 0    1231113600000000000         Qatar   Saudi Arabia        0.0        0.0
# 1    1234310400000000000     Argentina         France        2.0        0.0
# 2    1234310400000000000          Iran    South Korea        1.0        1.0
# 3    1234310400000000000     Australia          Japan        0.0        0.0
# 4    1234310400000000000       England          Spain        0.0        2.0
# ..                   ...           ...            ...        ...        ...
# 919  1664236800000000000       Ecuador          Japan        0.0        0.0
# 920  1664236800000000000          Iran        Senegal        1.0        1.0
# 921  1664236800000000000      Cameroon    South Korea        0.0        1.0
# 922  1664236800000000000  Saudi Arabia  United States        0.0        0.0
# 923  1664236800000000000      Portugal          Spain        0.0        1.0
#
# [924 rows x 5 columns]

# %%
df['date'] = pd.to_datetime(df['date'])
df
# Out:
#           date     home_team      away_team home_score away_score
# 0   2009-01-05         Qatar   Saudi Arabia        0.0        0.0
# 1   2009-02-11     Argentina         France        2.0        0.0
# 2   2009-02-11          Iran    South Korea        1.0        1.0
# 3   2009-02-11     Australia          Japan        0.0        0.0
# 4   2009-02-11       England          Spain        0.0        2.0
# ..         ...           ...            ...        ...        ...
# 919 2022-09-27       Ecuador          Japan        0.0        0.0
# 920 2022-09-27          Iran        Senegal        1.0        1.0
# 921 2022-09-27      Cameroon    South Korea        0.0        1.0
# 922 2022-09-27  Saudi Arabia  United States        0.0        0.0
# 923 2022-09-27      Portugal          Spain        0.0        1.0
#
# [924 rows x 5 columns]

# %%
df['score'] = df['home_score'] - df['away_score']
df = df[['date', 'home_team', 'away_team', 'score']]
df
# Out:
#           date     home_team      away_team score
# 0   2009-01-05         Qatar   Saudi Arabia   0.0
# 1   2009-02-11     Argentina         France   2.0
# 2   2009-02-11          Iran    South Korea   0.0
# 3   2009-02-11     Australia          Japan   0.0
# 4   2009-02-11       England          Spain  -2.0
# ..         ...           ...            ...   ...
# 919 2022-09-27       Ecuador          Japan   0.0
# 920 2022-09-27          Iran        Senegal   0.0
# 921 2022-09-27      Cameroon    South Korea  -1.0
# 922 2022-09-27  Saudi Arabia  United States   0.0
# 923 2022-09-27      Portugal          Spain  -1.0
#
# [924 rows x 4 columns]

# %% [markdown]
# ## Modeling

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df[['date', 'home_team', 'away_team']],
    df['score'],
    test_size=0.3,
    train_size=0.7
)
